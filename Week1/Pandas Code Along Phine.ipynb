# %% [markdown]
# ## Import Libraries

# %%
import numpy as np #import first the libraries

# %%
import pandas as pd

# %% [markdown]
# ## Get Data from files
# functions used:
# - pd.read_csv()
# - pd.read_excel()
#
# - df.shape
#
# - df.head()

# %%
# get data
file1 = pd.read_csv('file1.csv') #if im in the same directory as the file lies, only need name
# if its in a differen directory you have to put the path in there
#file1 = pd.read_csv('Users/josephiebiedermann/Desktop/DABC2021/IRONHACK/Week1/Day2/file1.csv')

# %%
file1.head()
#look at the top rows of the first file using df.head()
# Out:
#    CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0     44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1     96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2     43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3     21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4    190108    FL      F   995.00  252  348.0     0  17991      5      6
#
#      IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  430.0  466  28.000000      1  1901     C2     100.0
# 1  415.0  410   5.666667      0     0     T2       7.0
# 2  340.0  361   4.111111      0  2501     C2       5.0
# 3  407.0  399  27.277778      0  2208     T2      38.0
# 4  280.0  316   6.000000     28     0     C2       5.0

# %%
file1.describe(include = "all")
#use describe to review whats in the columns and some basic descriptive statistics
# Out:
#              CONTROLN STATE GENDER   HV1          IC1          IC4  \
# count     1007.000000  1007    967  1005  1007.000000  1006.000000
# unique            NaN    43      9   757          NaN          NaN
# top               NaN    CA      F     0          NaN          NaN
# freq              NaN   106    478     7          NaN          NaN
# mean     98913.029791   NaN    NaN   NaN   352.015889   445.059642
# std      58306.879885   NaN    NaN   NaN   173.937638   178.115476
# min         71.000000   NaN    NaN   NaN     0.000000     0.000000
# 25%      44930.500000   NaN    NaN   NaN   238.500000   325.000000
# 50%     101113.000000   NaN    NaN   NaN   319.000000   406.000000
# 75%     151559.000000   NaN    NaN   NaN   421.500000   527.000000
# max     191779.000000   NaN    NaN   NaN  1500.000000  1263.000000
#
#                HVP1   IC5        POBC1        POBC2          IC2          IC3  \
# count   1007.000000  1007  1007.000000  1007.000000  1006.000000  1007.000000
# ...

# %%
file2 = pd.read_csv('file2.txt', sep='\t')
#sep= is the sepertor for the text file, if we want to open txt file with read csv we need a seperator 
#'\t' is the seperator

# %%
file2.head() #breakages used so the table looks nicer
# Out:
#    CONTROLN STATE   GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  IC2  \
# 0    190579    CA        M  3200  310  343    83  17224     31     32  311
# 1     42997    FL        F  1567  392  409    27  18631      4     10  391
# 2    132896    OR        F   953  319  455     1  15729      3     45  379
# 3    120189    TX        M   492  244  301     3  10818      0     92  260
# 4    138829    AZ  feamale   847  185  308     0  11582      3     20  238
#
#    IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  333   3.106061      1     0     U1       4.0
# 1  434   6.562500      2  1808     C1       7.0
# 2  387  15.571429      2  4410     T1      25.0
# 3  284  19.375000      0     0     T2      25.0
# 4  225  11.500000     28  3601     T2      25.0

# %%
file2.shape #no breakages because just atribute of data fram object. No function assosiated with shape thats why no brackages, its an attribute not a function
#1015 rows index startes at position 0, does not include the header
#17 coloums
# Out:
# (1015, 17)

# %% [markdown]
# #### Read (import) all 4 data sources

# %%
#read in the other 2 excel files
# use pd.read_excel
file3 = pd.read_excel('file3.xlsx')

# %%
file4 = pd.read_excel('file4.xlsx')

# %% [markdown]
# Read function depending on the file
#
# - **excel** -> filename = pd.read_excel('filename.extention')
#
# - **csv** -> filename = pd.read_csv('filename.extention')
#
# - **txt** -> filename = pd.read_csv('filename.extention')
#
# the file name is a new df (data frame)

# %% [markdown]
# #### Get the shape of all 4 data sources
#
# - df.shape

# %%
file1.shape
# Out:
# (1007, 17)

# %%
file2.shape
# Out:
# (1015, 17)

# %%
file3.shape
# Out:
# (1000, 17)

# %%
file4.shape
# Out:
# (1006, 17)

# %% [markdown]
# #### Get the headers of all 4 data sources
# - df.head()

# %%
file1.head()
# Out:
#    CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0     44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1     96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2     43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3     21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4    190108    FL      F   995.00  252  348.0     0  17991      5      6
#
#      IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  430.0  466  28.000000      1  1901     C2     100.0
# 1  415.0  410   5.666667      0     0     T2       7.0
# 2  340.0  361   4.111111      0  2501     C2       5.0
# 3  407.0  399  27.277778      0  2208     T2      38.0
# 4  280.0  316   6.000000     28     0     C2       5.0

# %%
file2.head()
# Out:
#    CONTROLN STATE   GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  IC2  \
# 0    190579    CA        M  3200  310  343    83  17224     31     32  311
# 1     42997    FL        F  1567  392  409    27  18631      4     10  391
# 2    132896    OR        F   953  319  455     1  15729      3     45  379
# 3    120189    TX        M   492  244  301     3  10818      0     92  260
# 4    138829    AZ  feamale   847  185  308     0  11582      3     20  238
#
#    IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  333   3.106061      1     0     U1       4.0
# 1  434   6.562500      2  1808     C1       7.0
# 2  387  15.571429      2  4410     T1      25.0
# 3  284  19.375000      0     0     T2      25.0
# 4  225  11.500000     28  3601     T2      25.0

# %%
file3.head()
# Out:
#    CONTROLN      STATE GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  IC2  \
# 0    119966         TX      F   321  225  281     0   9372      3     68  264
# 1    152470         CA      F  5725  610  807    97  53158     13     22  763
# 2     48527         AL   Male   931  407  496     0  17743      0     65  502
# 3    171528         CA      F  1895  317  471    46  17431     10     62  389
# 4     50122  Tennessee      F   715  318  370     2  12416      0     75  340
#
#    IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  243   8.058824      0  3212     T3      11.0
# 1  698  23.727273      0     0     S1      45.0
# 2  439   4.416667      2     0     R3       3.0
# 3  405   6.705882      0  5501     R2       5.0
# 4  352   9.250000      2     0     T1      10.0

# %%
file4.head()
# Out:
#    CONTROLN STATE GENDER      HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  IC2  \
# 0    186307    CA      M  AAA1229  345  438     3  15915      2     58  388
# 1     34174    WV      F      529  198  291     0  10816      0     80  218
# 2    101388    MO      M      526  340  342     0   9687      0     89  348
# 3    159472    CA      F      621  231  279     0   6184     43     41  237
# 4    179143    WA   male     1688  496  564    35  22963      2     63  520
#
#    IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  417  16.142857      1  2511     C2      20.0
# 1  257   6.083333      2  3001     T2      12.0
# 2  321   5.800000      1  5501     R2      10.0
# 3  272  11.666667      1  1512     R3      15.0
# 4  521  23.900000      1  3709     T1      25.0

# %% [markdown]
# ## Merge Data Frames
#
# functions used:
# - df.columns
# - pd.dataframe()
# - pd.concat([df1,df2], axis= 0 or 1)

# %%
# check if we have a match in column headers in order to combine data sources (file1,2,3,4)

# %%
file4.columns #to get all the columns from the data source 
# column names need to be the same!!!
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'DOB', 'DOMAIN',
#        'TARGET_D'],
#       dtype='object')

# %%
file3.columns
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'DOB', 'DOMAIN',
#        'TARGET_D'],
#       dtype='object')

# %%
# pick which coulmn names should be used
column_names = file1.columns # create column names
print(column_names)
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'DOB', 'DOMAIN',
#        'TARGET_D'],
#       dtype='object')

# %%
#create new file called data where we want to merge our data
# with pd.dataframe(columns=variable)
data=pd.DataFrame(columns=column_names)

# %%
data.head()
# Out:
# Empty DataFrame
# Columns: [CONTROLN, STATE, GENDER, HV1, IC1, IC4, HVP1, IC5, POBC1, POBC2, IC2, IC3, AVGGIFT, TCODE, DOB, DOMAIN, TARGET_D]
# Index: []

# %%
data=pd.concat([data,file1],axis=0)
#axis 0 is rows we make, append along the rows, want to add rows
#axis 1 is column
#concat -> we merge data from new file data and file 1
# Reihenfolge von den beiden files ist egal

# %%
data.head()
# Out:
#   CONTROLN STATE GENDER      HV1  IC1    IC4 HVP1    IC5 POBC1 POBC2    IC2  \
# 0    44060    FL      M   AAA896  392  520.0    7  21975     6    16  430.0
# 1    96093    IL      M   537.00  365  473.0    0  19387     1    89  415.0
# 2    43333    FL      F   725.00  301  436.0    3  18837    11    17  340.0
# 3    21885    NC      M  AAA1095  401  413.0    7  14014     1    74  407.0
# 4   190108    FL      F   995.00  252  348.0    0  17991     5     6  280.0
#
#    IC3    AVGGIFT TCODE   DOB DOMAIN  TARGET_D
# 0  466  28.000000     1  1901     C2     100.0
# 1  410   5.666667     0     0     T2       7.0
# 2  361   4.111111     0  2501     C2       5.0
# 3  399  27.277778     0  2208     T2      38.0
# 4  316   6.000000    28     0     C2       5.0

# %%
data=pd.concat([data,file2],axis=0)

# %%
data.shape
# Out:
# (2022, 17)

# %%
data=pd.concat([data,file3],axis=0)

# %%
data.shape
# Out:
# (3022, 17)

# %%
data=pd.concat([file4,data],axis=0)
#if you run this cell more then once (a concat) you will append all the data again and you will have it in double
#if you did run it twice, go to cell > all output > clear, then go to cell you need to restart, go to cell and go to run all above

# %%
data.shape
# Out:
# (4028, 17)

# %% [markdown]
# ## Standardize header names
#
# what we do:
# - turn all headers into lower case
# - call columns
# - number of columns in df

# %%
data.columns[1]
#this will give me the second column header of data frame (df) 'data'
# Out:
# 'STATE'

# %%
#how many columns do we have?
len(data.columns)
# Out:
# 17

# %%
cols = []
for i in range(len(data.columns)):
    cols.append(data.columns[i].lower())
cols

#we want to make all the column headers into lower case 
#cols is a new empty list with all column headers that are lower case
# Out:
# ['controln',
#  'state',
#  'gender',
#  'hv1',
#  'ic1',
#  'ic4',
#  'hvp1',
#  'ic5',
#  'pobc1',
#  'pobc2',
#  'ic2',
#  'ic3',
#  'avggift',
#  'tcode',
#  'dob',
#  'domain',
#  'target_d']

# %%
data.columns = cols
# all column names are now replaced with the lower case column names

# %%
data.head()
#to check if it worked
# yes it worked, all column headers are now lower case
# Out:
#   controln state gender      hv1  ic1    ic4 hvp1    ic5 pobc1 pobc2    ic2  \
# 0   186307    CA      M  AAA1229  345  438.0    3  15915     2    58  388.0
# 1    34174    WV      F      529  198  291.0    0  10816     0    80  218.0
# 2   101388    MO      M      526  340  342.0    0   9687     0    89  348.0
# 3   159472    CA      F      621  231  279.0    0   6184    43    41  237.0
# 4   179143    WA   male     1688  496  564.0   35  22963     2    63  520.0
#
#    ic3    avggift tcode   dob domain  target_d
# 0  417  16.142857     1  2511     C2      20.0
# 1  257   6.083333     2  3001     T2      12.0
# 2  321   5.800000     1  5501     R2      10.0
# 3  272  11.666667     1  1512     R3      15.0
# 4  521  23.900000     1  3709     T1      25.0

# %% [markdown]
# ### examining columns an looking for epty cells
#
# what we do:
# - check the data types in the columns
#
# functions used:
# - df.dtypes
# - df.info()
# - df.isna()
# - df.drop()

# %%
# check data types of df
data.dtypes

#object because there are mostly strings in those columns
# float 64 64 decimal places
# Out:
# controln     object
# state        object
# gender       object
# hv1          object
# ic1          object
# ic4         float64
# hvp1         object
# ic5          object
# pobc1        object
# pobc2        object
# ic2         float64
# ic3          object
# avggift     float64
# tcode        object
# dob          object
# domain       object
# target_d    float64
# dtype: object

# %%
#lets look at how many NA values we have in each column
data.info()
# shows us how mnay non nulls we have - so we can see how many nulls we have per columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4028 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   controln  4028 non-null   object
#  1   state     4028 non-null   object
#  2   gender    3892 non-null   object
#  3   hv1       4026 non-null   object
#  4   ic1       4028 non-null   object
#  5   ic4       4027 non-null   float64
#  6   hvp1      4028 non-null   object
#  7   ic5       4028 non-null   object
#  8   pobc1     4028 non-null   object
#  9   pobc2     4028 non-null   object
#  10  ic2       4027 non-null   float64
#  11  ic3       4028 non-null   object
#  12  avggift   4028 non-null   float64
#  13  tcode     4028 non-null   object
#  14  dob       4028 non-null   object
#  15  domain    4028 non-null   object
#  16  target_d  4028 non-null   float64
# dtypes: float64(4), object(13)
# memory usage: 566.4+ KB

# %%
#we can easily create a df of missing values using isna()
# isna() function is looking through the columns if is it NA or not? gives true (if it is NA) or false (if its not NA)

missingdata=data.isna()
missingdata.head()
# Out:
#    controln  state  gender    hv1    ic1    ic4   hvp1    ic5  pobc1  pobc2  \
# 0     False  False   False  False  False  False  False  False  False  False
# 1     False  False   False  False  False  False  False  False  False  False
# 2     False  False   False  False  False  False  False  False  False  False
# 3     False  False   False  False  False  False  False  False  False  False
# 4     False  False   False  False  False  False  False  False  False  False
#
#      ic2    ic3  avggift  tcode    dob  domain  target_d
# 0  False  False    False  False  False   False     False
# 1  False  False    False  False  False   False     False
# 2  False  False    False  False  False   False     False
# 3  False  False    False  False  False   False     False
# 4  False  False    False  False  False   False     False

# %%
#what about showing the % nulls - heres one technique
#the above data frame is a boolean ie 1s and 0s - so if we add them up we can see a count of actual values 

missingdata.sum()/len(data)

#what does this look like from maths? 
#Summing up all the values in a column and then dividing by the total number is the mean.
#this is the same as missingdata.mean()
# Out:
# controln    0.000000
# state       0.000000
# gender      0.033764
# hv1         0.000497
# ic1         0.000000
# ic4         0.000248
# hvp1        0.000000
# ic5         0.000000
# pobc1       0.000000
# pobc2       0.000000
# ic2         0.000248
# ic3         0.000000
# avggift     0.000000
# tcode       0.000000
# dob         0.000000
# domain      0.000000
# target_d    0.000000
# dtype: float64

# %%
#to summarise this in one line of code and round the values 
data.isna().mean().round(4) *100
#percentages of columns that are empty
# Out:
# controln    0.00
# state       0.00
# gender      3.38
# hv1         0.05
# ic1         0.00
# ic4         0.02
# hvp1        0.00
# ic5         0.00
# pobc1       0.00
# pobc2       0.00
# ic2         0.02
# ic3         0.00
# avggift     0.00
# tcode       0.00
# dob         0.00
# domain      0.00
# target_d    0.00
# dtype: float64

# %%
# lets assume we wanted to drop a single column due to poor coverage across all data sets: domain 

data = data.drop(['domain'],axis=1)

# axis 1 because we want all values in columns not in rows

# %% [markdown]
# ![Screenshot%202021-03-23%20at%2012.23.41.png](attachment:Screenshot%202021-03-23%20at%2012.23.41.png)
# - axis 1 -> values in columns
# - axis 2 -> values in rows

# %%
data.head()
#see what we changed
# we dropped the column domain
# Out:
#   controln state gender      hv1  ic1    ic4 hvp1    ic5 pobc1 pobc2    ic2  \
# 0   186307    CA      M  AAA1229  345  438.0    3  15915     2    58  388.0
# 1    34174    WV      F      529  198  291.0    0  10816     0    80  218.0
# 2   101388    MO      M      526  340  342.0    0   9687     0    89  348.0
# 3   159472    CA      F      621  231  279.0    0   6184    43    41  237.0
# 4   179143    WA   male     1688  496  564.0   35  22963     2    63  520.0
#
#    ic3    avggift tcode   dob  target_d
# 0  417  16.142857     1  2511      20.0
# 1  257   6.083333     2  3001      12.0
# 2  321   5.800000     1  5501      10.0
# 3  272  11.666667     1  1512      15.0
# 4  521  23.900000     1  3709      25.0

# %%
#this time lets drop a few columns in one hit by choosing which we want to keep - also rearranging the columns

data=data[['controln', 'state', 'gender', 'hv1', 'hvp1',
       'pobc1', 'pobc2','avggift', 'target_d','ic1','ic2','ic3','ic4','ic5']]

# %%
data.head()
#see the changes we made on the columns
#we dropped a few columns and changed the order
# Out:
#   controln state gender      hv1 hvp1 pobc1 pobc2    avggift  target_d  ic1  \
# 0   186307    CA      M  AAA1229    3     2    58  16.142857      20.0  345
# 1    34174    WV      F      529    0     0    80   6.083333      12.0  198
# 2   101388    MO      M      526    0     0    89   5.800000      10.0  340
# 3   159472    CA      F      621    0    43    41  11.666667      15.0  231
# 4   179143    WA   male     1688   35     2    63  23.900000      25.0  496
#
#      ic2  ic3    ic4    ic5
# 0  388.0  417  438.0  15915
# 1  218.0  257  291.0  10816
# 2  348.0  321  342.0   9687
# 3  237.0  272  279.0   6184
# 4  520.0  521  564.0  22963

# %%
#lets rename a few of the columns to sensible names
# create dict where we replace the column headers like in dict
data = data.rename(columns={ 'controln':'id','hv1':'median_home_val', 'ic1':'median_household_income'})

# %%
data.head()
#see the changes we made on the column header names
# Out:
#        id state gender median_home_val hvp1 pobc1 pobc2    avggift  target_d  \
# 0  186307    CA      M         AAA1229    3     2    58  16.142857      20.0
# 1   34174    WV      F             529    0     0    80   6.083333      12.0
# 2  101388    MO      M             526    0     0    89   5.800000      10.0
# 3  159472    CA      F             621    0    43    41  11.666667      15.0
# 4  179143    WA   male            1688   35     2    63  23.900000      25.0
#
#   median_household_income    ic2  ic3    ic4    ic5
# 0                     345  388.0  417  438.0  15915
# 1                     198  218.0  257  291.0  10816
# 2                     340  348.0  321  342.0   9687
# 3                     231  237.0  272  279.0   6184
# 4                     496  520.0  521  564.0  22963

# %% [markdown]
# ## reset the index
#
# after concating you need to re run the index
#
# function used:
# - df.reset_index(drop=True, inplace=True)
#
# ![Screenshot%202021-03-23%20at%2014.07.51.png](attachment:Screenshot%202021-03-23%20at%2014.07.51.png)
#
# if you concat the data frames it stayes with the index of the first df (1)
# you need to reset the index to include the rows of the concated df (2,3,4)

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4028 entries, 0 to 4027
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       4028 non-null   object
#  1   state                    4028 non-null   object
#  2   gender                   3892 non-null   object
#  3   median_home_val          4026 non-null   object
#  4   hvp1                     4028 non-null   object
#  5   pobc1                    4028 non-null   object
#  6   pobc2                    4028 non-null   object
#  7   avggift                  4028 non-null   float64
#  8   target_d                 4028 non-null   float64
#  9   median_household_income  4028 non-null   object
#  10  ic2                      4027 non-null   float64
#  11  ic3                      4028 non-null   object
#  12  ic4                      4027 non-null   float64
#  13  ic5                      4028 non-null   object
# ...

# %% [markdown]
# ### Convert data structures to df
#
# ![Screenshot%202021-03-23%20at%2016.02.10.png](attachment:Screenshot%202021-03-23%20at%2016.02.10.png)

# %% [markdown]
# ### Filtering and Subsetting

# %%
#method 1 focus on just male donors in florida 

data[(data["state"]=="FL") & (data["gender"]=='M')]

#index positions are retained, but values inbetween are dropped

# no new df is created, just a temporaroy sub set
# just running a query on the data set data
# if new df then assign to a variabel -> new_df = [(data["state"]=="FL") & (data["gender"]=='M')]
# Out:
#          id state gender median_home_val hvp1 pobc1 pobc2    avggift  \
# 11     6555    FL      M            3125   90    42    15   6.098901
# 38    40786    FL      M            1163   14     8    33  11.375000
# 51    37090    FL      M            1363   24    18    23  13.700000
# 52      427    FL      M             709    0     3     8   9.545455
# 99    33420    FL      M             702    1     8    45  12.219512
# ...     ...   ...    ...             ...  ...   ...   ...        ...
# 3761  36774    FL      M             902    0    21    32  10.000000
# 3937  36081    FL      M            1201    8     2    36   6.352941
# 3982  33355    FL      M             700    1     5    47  12.923077
# 3989  33615    FL      M             563    1     5    36  14.571429
# 3996  35328    FL      M            1454   14     7    28  11.642857
#
#       target_d median_household_income    ic2  ic3    ic4    ic5
# 11        10.0                     616  759.0  714  817.0  37628
# ...

# %%
# Alternative 2
data.query('gender=="M" & state=="FL" ')

# run this query where we look for this variabel
# Out:
#          id state gender median_home_val hvp1 pobc1 pobc2    avggift  \
# 11     6555    FL      M            3125   90    42    15   6.098901
# 38    40786    FL      M            1163   14     8    33  11.375000
# 51    37090    FL      M            1363   24    18    23  13.700000
# 52      427    FL      M             709    0     3     8   9.545455
# 99    33420    FL      M             702    1     8    45  12.219512
# ...     ...   ...    ...             ...  ...   ...   ...        ...
# 3761  36774    FL      M             902    0    21    32  10.000000
# 3937  36081    FL      M            1201    8     2    36   6.352941
# 3982  33355    FL      M             700    1     5    47  12.923077
# 3989  33615    FL      M             563    1     5    36  14.571429
# 3996  35328    FL      M            1454   14     7    28  11.642857
#
#       target_d median_household_income    ic2  ic3    ic4    ic5
# 11        10.0                     616  759.0  714  817.0  37628
# ...

# %%
# Alternative 3
data.loc[data.gender == "M"]

# loc with multiple conditions
data.loc[data.gender == "M"] #???
df.loc[['viper', 'sidewinder']]

# based on lable in data, label M
# is a list
# Out:
#           id state gender median_home_val hvp1 pobc1 pobc2    avggift  \
# 0     186307    CA      M         AAA1229    3     2    58  16.142857
# 2     101388    MO      M             526    0     0    89   5.800000
# 5     150799    CA      M         AAA1305    8    19    51   7.625000
# 11      6555    FL      M            3125   90    42    15   6.098901
# 12     20341    NC      M            1427   27     3    36   7.230769
# ...      ...   ...    ...             ...  ...   ...   ...        ...
# 4009  101290    MO      M             152    0     0    80   3.250000
# 4010   22779    SC      M             535    2     0    75  12.533333
# 4012   99066    IL      M             206    0     1    63   4.434783
# 4019  188421    OR      M             704    0     4    48   7.500000
# 4021   23930    SC      M             891    7     2    60   4.277778
#
#       target_d median_household_income    ic2  ic3    ic4    ic5
# ...

# %%
data['gender'].value_counts()

#how many rows in wich lable per column
# Out:
# F          1966
# M          1474
# male        128
# female      106
# Female       77
# U            69
# Male         33
# J            23
# feamale      15
# A             1
# Name: gender, dtype: int64

# %%
data['gender'].unique()
#gives an array of all uniue values in data set
# Out:
# array(['M', 'F', 'male', nan, 'Male', 'Female', 'female', 'U', 'J',
#        'feamale', 'A'], dtype=object)

# %%
#challenge1: view a filtered subset of the data where
#the average gift is over 10 dollars 

data.query('avggift > 10')

#or data.loc[data.avggift >= 10]
#or data[data['avggift'] > 10]
# Out:
#           id state  gender median_home_val hvp1 pobc1 pobc2    avggift  \
# 0     186307    CA       M         AAA1229    3     2    58  16.142857
# 3     159472    CA       F             621    0    43    41  11.666667
# 4     179143    WA    male            1688   35     2    63  23.900000
# 7      22817    SC       F             451    0     0    96  16.000000
# 14     38392    FL       F         AAA1119   11    67    26  20.000000
# ...      ...   ...     ...             ...  ...   ...   ...        ...
# 4017  173744    HI     NaN             798    2    14    55  20.000000
# 4018  179683    WA       F            1108    4     3    63  21.666667
# 4024   87395    MT  female             842    3     2    50  15.100000
# 4025   86779    ND       F             331    0     1    61  10.666667
# 4026   25214    NC  female            1823   43     1    62  12.000000
#
#       target_d median_household_income    ic2  ic3    ic4    ic5
# ...

# %%
#challenge 2: view a filtered subset of the data where
#the gender is M, state is florida and avg gift size is more than 10 dollars

data.query('gender == "M" & state == "FL" & avggift > 10')

# or data[(data["state"]=="FL") & (data["gender"]=='M') & (data["avggift"]>= 10)]
# or data.loc[(data.gender == 'M') & (data.state == 'FL') & (data.avggift >= 10)]
# Out:
#          id state gender median_home_val hvp1 pobc1 pobc2    avggift  \
# 38    40786    FL      M            1163   14     8    33  11.375000
# 51    37090    FL      M            1363   24    18    23  13.700000
# 99    33420    FL      M             702    1     8    45  12.219512
# 199   46129    FL      M             973    7     3    32  13.142857
# 261   44433    FL      M             606    2     6    24  11.000000
# ...     ...   ...    ...             ...  ...   ...   ...        ...
# 3543  45134    FL      M             736    0    12    11  12.666667
# 3643  43564    FL      M            1165    9     0    38  20.000000
# 3982  33355    FL      M             700    1     5    47  12.923077
# 3989  33615    FL      M             563    1     5    36  14.571429
# 3996  35328    FL      M            1454   14     7    28  11.642857
#
#       target_d median_household_income    ic2  ic3    ic4    ic5
# 38         5.0                     402  446.0  495  552.0  19090
# ...

# %% [markdown]
# # create copy of df

# %%
#before we apply any lasting filter to our data frame lets create a new version which we can play with
# so that the original data frame wont be affected

tempdata=data.copy()

#new data frame
# every time we want to use it now we have to re

# %% [markdown]
# ## create a new filtered df from a subset

# %%
#create a filtered dataframe from our M gender subset 
filtered =data[data['gender']=='M']

# filtered = new filteres df

# %%
filtered.shape
# Out:
# (1474, 14)

# %%
filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1474 entries, 0 to 1473
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       1474 non-null   object
#  1   state                    1474 non-null   object
#  2   gender                   1474 non-null   object
#  3   median_home_val          1473 non-null   object
#  4   hvp1                     1474 non-null   object
#  5   pobc1                    1474 non-null   object
#  6   pobc2                    1474 non-null   object
#  7   avggift                  1474 non-null   float64
#  8   target_d                 1474 non-null   float64
#  9   median_household_income  1474 non-null   object
#  10  ic2                      1474 non-null   float64
#  11  ic3                      1474 non-null   object
#  12  ic4                      1474 non-null   float64
#  13  ic5                      1474 non-null   object
# ...

# %%
#notice we need to reset the index 
filtered.reset_index(drop=True, inplace=True)

# we need a new index because if we dont, it would have the same index from before
# we reset it so we have a new index
# we have to do it because its from a subset

# %% [markdown]
# #### resetting the index
#
# always make sure if you need to reset your index

# %%
filtered.head()
# Out:
#        id state gender median_home_val hvp1 pobc1 pobc2    avggift  target_d  \
# 0  186307    CA      M         AAA1229    3     2    58  16.142857      20.0
# 1  101388    MO      M             526    0     0    89   5.800000      10.0
# 2  150799    CA      M         AAA1305    8    19    51   7.625000      15.0
# 3    6555    FL      M            3125   90    42    15   6.098901      10.0
# 4   20341    NC      M            1427   27     3    36   7.230769       3.0
#
#   median_household_income    ic2  ic3    ic4    ic5
# 0                     345  388.0  417  438.0  15915
# 1                     340  348.0  321  342.0   9687
# 2                     257  275.0  376  393.0  10990
# 3                     616  759.0  714  817.0  37628
# 4                     367  435.0  456  525.0  24023

# %%
#use the index to display the first ten rows 
filtered[0:10]
# Out:
#        id state gender median_home_val hvp1 pobc1 pobc2    avggift  target_d  \
# 0  186307    CA      M         AAA1229    3     2    58  16.142857      20.0
# 1  101388    MO      M             526    0     0    89   5.800000      10.0
# 2  150799    CA      M         AAA1305    8    19    51   7.625000      15.0
# 3    6555    FL      M            3125   90    42    15   6.098901      10.0
# 4   20341    NC      M            1427   27     3    36   7.230769       3.0
# 5  122090    TX      M             405    0     6    65   4.785714      20.0
# 6  103290    MO      M             736    0     4    62   9.600000      16.0
# 7  154745    CA      M             996    4     2    60  10.000000       5.0
# 8  162494    CA      M            2375   88    18    60  21.875000      30.0
# 9  145905    CA      M            2328   74    20    47  25.000000      20.0
#
#   median_household_income    ic2  ic3    ic4    ic5
# 0                     345  388.0  417  438.0  15915
# ...

# %%
# use the index to display 3 columns, first ten rows 
filtered[['gender', 'ic2', 'ic3']][0:10]

#this is a subframe
# Out:
#   gender    ic2  ic3
# 0      M  388.0  417
# 1      M  348.0  321
# 2      M  275.0  376
# 3      M  759.0  714
# 4      M  435.0  456
# 5      M  340.0  349
# 6      M  646.0  654
# 7      M  419.0  382
# 8      M  516.0  465
# 9      M  469.0  434

# %%
#use loc to return a selected row 
filtered.loc[1]

#location
# Out:
# id                         101388
# state                          MO
# gender                          M
# median_home_val               526
# hvp1                            0
# pobc1                           0
# pobc2                          89
# avggift                       5.8
# target_d                       10
# median_household_income       340
# ic2                           348
# ic3                           321
# ic4                           342
# ic5                          9687
# Name: 1, dtype: object

# %%
#use iloc to return first 10 rows and the first 4 columns 

filtered.iloc[1:10,0:4]

#index location
#only integer based
#first part rows
#second part columns

#dosnt make sense if your columns are not in order, then use 

# pulling out a subsection of the data
# Out:
#        id state gender median_home_val
# 1  101388    MO      M             526
# 2  150799    CA      M         AAA1305
# 3    6555    FL      M            3125
# 4   20341    NC      M            1427
# 5  122090    TX      M             405
# 6  103290    MO      M             736
# 7  154745    CA      M             996
# 8  162494    CA      M            2375
# 9  145905    CA      M            2328

# %%
# tip : its possible to set the index from any column eg ID

filtered2=filtered.reset_index().set_index('id')
filtered2.head()
#in which case using iloc and loc would give very different results
# Out:
#         index state gender median_home_val hvp1 pobc1 pobc2    avggift  \
# id
# 186307      0    CA      M         AAA1229    3     2    58  16.142857
# 101388      1    MO      M             526    0     0    89   5.800000
# 150799      2    CA      M         AAA1305    8    19    51   7.625000
# 6555        3    FL      M            3125   90    42    15   6.098901
# 20341       4    NC      M            1427   27     3    36   7.230769
#
#         target_d median_household_income    ic2  ic3    ic4    ic5
# id
# 186307      20.0                     345  388.0  417  438.0  15915
# 101388      10.0                     340  348.0  321  342.0   9687
# 150799      15.0                     257  275.0  376  393.0  10990
# 6555        10.0                     616  759.0  714  817.0  37628
# 20341        3.0                     367  435.0  456  525.0  24023

# %%
filtered2.sort_index()

#we sort now by the index (in this case its now the ID)
# Out:
#         index       state gender median_home_val hvp1 pobc1 pobc2    avggift  \
# id
# 12       1468          MO      M             334    0     1    77  14.720000
# 159       105          MN      M             530    1     1    78   9.310345
# 220        18          IL      M             550    0     1    71   5.545455
# 368       866          CA      M            2257   78     8    50   6.500000
# 427        17          FL      M             709    0     3     8   9.545455
# ...       ...         ...    ...             ...  ...   ...   ...        ...
# 190840    835          IL      M             485    0     3    60  21.250000
# 190920    589  California      M             916    5    19    51  22.000000
# 191056    413        Cali      M            5667   98    11    35  28.833333
# 191663    606          OR      M             538    0     6    31   9.307692
# 191779    449          FL      M            1432   24     0    44  25.000000
#
# ...

# %%
#when reviewing subsets it is often smart to reconfigure how many rows you will see max

pd.set_option('display.max_rows', 20)

# %%
filtered.loc[:218]
# Out:
#          id state gender median_home_val hvp1 pobc1 pobc2    avggift  \
# 0    186307    CA      M         AAA1229    3     2    58  16.142857
# 1    101388    MO      M             526    0     0    89   5.800000
# 2    150799    CA      M         AAA1305    8    19    51   7.625000
# 3      6555    FL      M            3125   90    42    15   6.098901
# 4     20341    NC      M            1427   27     3    36   7.230769
# ..      ...   ...    ...             ...  ...   ...   ...        ...
# 214   21539    NC      M             996   15     1    73   3.655172
# 215  125277    TX      M            1136   11     4    47  36.363636
# 216  116329    TX      M            2196   66    12    34  10.625000
# 217  103857    MO      M             278    1     0    67  17.500000
# 218  146940    CA      M            5679   97     4    44   8.500000
#
#      target_d median_household_income    ic2  ic3    ic4    ic5
# 0        20.0                     345  388.0  417  438.0  15915
# ...

# %%
filtered.iloc[:218]
# Out:
#          id state gender median_home_val hvp1 pobc1 pobc2    avggift  \
# 0    186307    CA      M         AAA1229    3     2    58  16.142857
# 1    101388    MO      M             526    0     0    89   5.800000
# 2    150799    CA      M         AAA1305    8    19    51   7.625000
# 3      6555    FL      M            3125   90    42    15   6.098901
# 4     20341    NC      M            1427   27     3    36   7.230769
# ..      ...   ...    ...             ...  ...   ...   ...        ...
# 213  160773    CA      M            1679   34     9    51   7.600000
# 214   21539    NC      M             996   15     1    73   3.655172
# 215  125277    TX      M            1136   11     4    47  36.363636
# 216  116329    TX      M            2196   66    12    34  10.625000
# 217  103857    MO      M             278    1     0    67  17.500000
#
#      target_d median_household_income    ic2  ic3    ic4    ic5
# 0        20.0                     345  388.0  417  438.0  15915
# ...

# %% [markdown]
# difference between iloc and loc

# %% [markdown]
# ## Data cleaning steps

# %%
#reverting back to our temp data copy
# lets look at the data types. any data type worth changing? 
tempdata.dtypes
# Out:
# id                          object
# state                       object
# gender                      object
# median_home_val             object
# hvp1                        object
# pobc1                       object
# pobc2                       object
# avggift                    float64
# target_d                   float64
# median_household_income     object
# ic2                        float64
# ic3                         object
# ic4                        float64
# ic5                         object
# dtype: object

# %%
#focus on float data types 

# what are the data with the data type xy
tempdata.select_dtypes('float64')

#float64 64 refers to storage type bits
# Out:
#       target_d    ic2    ic4
# 0         20.0  388.0  438.0
# 1         12.0  218.0  291.0
# 2         10.0  348.0  342.0
# 3         15.0  237.0  279.0
# 4         25.0  520.0  564.0
# ...        ...    ...    ...
# 4023      10.0  454.0  447.0
# 4024      20.0  286.0  388.0
# 4025      11.0  172.0  266.0
# 4026      25.0  552.0  567.0
# 4027      12.0  713.0  776.0
#
# [4028 rows x 3 columns]

# %%
#simple change from float to int type would drop the decimals 
tempdata['avggift'] = tempdata['avggift'].astype('int')

# function df.astype()

# %%
#focus on the object data types 
tempdata.select_dtypes('object')
# Out:
#           id state  gender median_home_val hvp1 pobc1 pobc2  \
# 0     186307    CA       M         AAA1229    3     2    58
# 1      34174    WV       F             529    0     0    80
# 2     101388    MO       M             526    0     0    89
# 3     159472    CA       F             621    0    43    41
# 4     179143    WA    male            1688   35     2    63
# ...      ...   ...     ...             ...  ...   ...   ...
# 4023  179863    WA    male            1253    7    12    57
# 4024   87395    MT  female             842    3     2    50
# 4025   86779    ND       F             331    0     1    61
# 4026   25214    NC  female            1823   43     1    62
# 4027   79641    WI       F            1244   25     1    64
#
#      median_household_income  ic3    ic5
# 0                        345  417  15915
# 1                        198  257  10816
# 2                        340  321   9687
# 3                        231  272   6184
# ...

# %% [markdown]
# although tempting to force an object into a float using as type :
# tempdata['median_home_val'] = tempdata['median_home_val'].astype('float', errors='ignore')
# we know some values of the data are strings and this could produce an error

# %%
#lets have a look at all the numeric data 

tempdata._get_numeric_data()
# Out:
#       avggift  target_d    ic2    ic4
# 0          16      20.0  388.0  438.0
# 1           6      12.0  218.0  291.0
# 2           5      10.0  348.0  342.0
# 3          11      15.0  237.0  279.0
# 4          23      25.0  520.0  564.0
# ...       ...       ...    ...    ...
# 4023        9      10.0  454.0  447.0
# 4024       15      20.0  286.0  388.0
# 4025       10      11.0  172.0  266.0
# 4026       12      25.0  552.0  567.0
# 4027        9      12.0  713.0  776.0
#
# [4028 rows x 4 columns]

# %%
#do a data type change for column and replace non float values with NaN

tempdata['median_home_val'] =  pd.to_numeric(tempdata['median_home_val'], errors='coerce')

#we handel data dont force is with type

# %%
tempdata._get_numeric_data()
# Out:
#       median_home_val  avggift  target_d    ic2    ic4
# 0                 NaN       16      20.0  388.0  438.0
# 1               529.0        6      12.0  218.0  291.0
# 2               526.0        5      10.0  348.0  342.0
# 3               621.0       11      15.0  237.0  279.0
# 4              1688.0       23      25.0  520.0  564.0
# ...               ...      ...       ...    ...    ...
# 4023           1253.0        9      10.0  454.0  447.0
# 4024            842.0       15      20.0  286.0  388.0
# 4025            331.0       10      11.0  172.0  266.0
# 4026           1823.0       12      25.0  552.0  567.0
# 4027           1244.0        9      12.0  713.0  776.0
#
# [4028 rows x 5 columns]

# %%
# do the same for median household income, ic3 and ic5

# %%
tempdata['median_household_income'] =  pd.to_numeric(tempdata['median_household_income'], errors='coerce')

# %%
tempdata._get_numeric_data()
# Out:
#       median_home_val  avggift  target_d  median_household_income    ic2  \
# 0                 NaN       16      20.0                      345  388.0
# 1               529.0        6      12.0                      198  218.0
# 2               526.0        5      10.0                      340  348.0
# 3               621.0       11      15.0                      231  237.0
# 4              1688.0       23      25.0                      496  520.0
# ...               ...      ...       ...                      ...    ...
# 4023           1253.0        9      10.0                      325  454.0
# 4024            842.0       15      20.0                      264  286.0
# 4025            331.0       10      11.0                      165  172.0
# 4026           1823.0       12      25.0                      544  552.0
# 4027           1244.0        9      12.0                      672  713.0
#
#         ic4
# 0     438.0
# 1     291.0
# 2     342.0
# 3     279.0
# 4     564.0
# ...

# %%
tempdata['ic3'] =  pd.to_numeric(tempdata['ic3'], errors='coerce')

# %%
tempdata['ic5'] =  pd.to_numeric(tempdata['ic5'], errors='coerce')

# %%
tempdata._get_numeric_data()
# Out:
#       median_home_val  avggift  target_d  median_household_income    ic2  ic3  \
# 0                 NaN       16      20.0                      345  388.0  417
# 1               529.0        6      12.0                      198  218.0  257
# 2               526.0        5      10.0                      340  348.0  321
# 3               621.0       11      15.0                      231  237.0  272
# 4              1688.0       23      25.0                      496  520.0  521
# ...               ...      ...       ...                      ...    ...  ...
# 4023           1253.0        9      10.0                      325  454.0  374
# 4024            842.0       15      20.0                      264  286.0  370
# 4025            331.0       10      11.0                      165  172.0  232
# 4026           1823.0       12      25.0                      544  552.0  552
# 4027           1244.0        9      12.0                      672  713.0  743
#
#         ic4      ic5
# ...

# %%
tempdata.info()

#we can see that the 3 colum values are now int or float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4028 entries, 0 to 4027
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       4028 non-null   object
#  1   state                    4028 non-null   object
#  2   gender                   3892 non-null   object
#  3   median_home_val          4018 non-null   float64
#  4   hvp1                     4028 non-null   object
#  5   pobc1                    4028 non-null   object
#  6   pobc2                    4028 non-null   object
#  7   avggift                  4028 non-null   int64
#  8   target_d                 4028 non-null   float64
#  9   median_household_income  4028 non-null   int64
#  10  ic2                      4027 non-null   float64
#  11  ic3                      4028 non-null   int64
#  12  ic4                      4027 non-null   float64
#  13  ic5                      4022 non-null   float64
# ...

# %% [markdown]
# ## how to pull out our data as an output file

# %%
tempdata.to_csv('tempdataoutput.csv', index = False)

# %%
# this is saved in the same dispository as the tempdata is stored
# if you want to save it somewhere else you need to put in the path

# %% [markdown]
# ![Screenshot%202021-03-23%20at%2016.02.29.png](attachment:Screenshot%202021-03-23%20at%2016.02.29.png)
